# %%
import pandas as pd
df = pd.read_csv("C:/TechLabs/PandasApp/myenv_1/gym_membership_prediction_with_professional_status.csv")
df
# Out:
#       User ID  Age  Gender  Annual Income Membership Type  \
# 0           1   62   Other         135305         Premium
# 1           2   65    Male          59056           Basic
# 2           3   18    Male          63857           Basic
# 3           4   21    Male         135072           Basic
# 4           5   21  Female          59344           Basic
# ...       ...  ...     ...            ...             ...
# 3995     3996   40    Male         127601         Premium
# 3996     3997   40  Female          77944         Premium
# 3997     3998   62    Male          33154           Basic
# 3998     3999   55  Female         139822         Premium
# 3999     4000   52  Female          61604           Basic
#
#       Membership Duration  Frequency of Visit Preferred Time  \
# 0                      46                   2      Afternoon
# 1                      26                   6      Afternoon
# 2                      46                   2      Afternoon
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       User ID  Age  Gender  Annual Income Membership Type  \
# 0           1   62   Other         135305         Premium
# 1           2   65    Male          59056           Basic
# 2           3   18    Male          63857           Basic
# 3           4   21    Male         135072           Basic
# 4           5   21  Female          59344           Basic
# ...       ...  ...     ...            ...             ...
# 3995     3996   40    Male         127601         Premium
# 3996     3997   40  Female          77944         Premium
# 3997     3998   62    Male          33154           Basic
# 3998     3999   55  Female         139822         Premium
# 3999     4000   52  Female          61604           Basic
#
#       Membership Duration  Frequency of Visit Preferred Time  \
# 0                      46                   2      Afternoon
# 1                      26                   6      Afternoon
# ...

# %% [markdown]
# #checking the type of data inside the data frame

# %%
df.dtypes
# Out:
# User ID                   int64
# Age                       int64
# Gender                   object
# Annual Income             int64
# Membership Type          object
# Membership Duration       int64
# Frequency of Visit        int64
# Preferred Time           object
# Previous Membership      object
# Marital Status           object
# Location                 object
# Promotion Response       object
# Health Condition         object
# Membership Prediction    object
# Professional             object
# Professional Status      object
# dtype: object

# %%
df
# Out:
#       User ID  Age  Gender  Annual Income Membership Type  \
# 0           1   62   Other         135305         Premium
# 1           2   65    Male          59056           Basic
# 2           3   18    Male          63857           Basic
# 3           4   21    Male         135072           Basic
# 4           5   21  Female          59344           Basic
# ...       ...  ...     ...            ...             ...
# 3995     3996   40    Male         127601         Premium
# 3996     3997   40  Female          77944         Premium
# 3997     3998   62    Male          33154           Basic
# 3998     3999   55  Female         139822         Premium
# 3999     4000   52  Female          61604           Basic
#
#       Membership Duration  Frequency of Visit Preferred Time  \
# 0                      46                   2      Afternoon
# 1                      26                   6      Afternoon
# 2                      46                   2      Afternoon
# ...

# %% [markdown]
# #First 15 Rows to see what it looks like approximately

# %%
df.head(15)
# Out:
#     User ID  Age  Gender  Annual Income Membership Type  Membership Duration  \
# 0         1   62   Other         135305         Premium                   46
# 1         2   65    Male          59056           Basic                   26
# 2         3   18    Male          63857           Basic                   46
# 3         4   21    Male         135072           Basic                   54
# 4         5   21  Female          59344           Basic                   36
# 5         6   57    Male         130879         Premium                   49
# 6         7   27  Female          99861             VIP                   12
# 7         8   37  Female         136521             VIP                   14
# 8         9   39  Female          36287         Premium                   15
# 9        10   68    Male          66916           Basic                   36
# 10       11   54  Female          87173         Premium                   56
# ...

# %% [markdown]
# #Statistics about the data frame

# %%
df.describe(include='all')
# Out:
#             User ID          Age Gender  Annual Income Membership Type  \
# count   4000.000000  4000.000000   4000    4000.000000            4000
# unique          NaN          NaN      3            NaN               3
# top             NaN          NaN   Male            NaN           Basic
# freq            NaN          NaN   1840            NaN            2434
# mean    2000.500000    43.633000    NaN   86346.917000             NaN
# std     1154.844867    15.182669    NaN   38029.388846             NaN
# min        1.000000    18.000000    NaN   20046.000000             NaN
# 25%     1000.750000    30.000000    NaN   53324.250000             NaN
# 50%     2000.500000    44.000000    NaN   86908.000000             NaN
# 75%     3000.250000    57.000000    NaN  120324.000000             NaN
# max     4000.000000    69.000000    NaN  149980.000000             NaN
#
#         Membership Duration  Frequency of Visit Preferred Time  \
# ...

# %% [markdown]
# #Sanity Check, calculation of zero values column wise

# %%
df.isnull().sum()
# Out:
# User ID                  0
# Age                      0
# Gender                   0
# Annual Income            0
# Membership Type          0
# Membership Duration      0
# Frequency of Visit       0
# Preferred Time           0
# Previous Membership      0
# Marital Status           0
# Location                 0
# Promotion Response       0
# Health Condition         0
# Membership Prediction    0
# Professional             0
# Professional Status      0
# dtype: int64

# %% [markdown]
# #Sanity Check, calculation of zero values row wise

# %%
df.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3995    0
# 3996    0
# 3997    0
# 3998    0
# 3999    0
# Length: 4000, dtype: int64

# %% [markdown]
# #unique values in column Professional Status

# %%
df['Professional Status'].unique()
# Out:
# array(['Retired', 'Student', 'Working Professional'], dtype=object)

# %%
df['Professional Status'].value_counts()
# Out:
# Professional Status
# Working Professional    2719
# Retired                  726
# Student                  555
# Name: count, dtype: int64

# %%
df['Professional Status']
# Out:
# 0                    Retired
# 1                    Retired
# 2                    Student
# 3                    Student
# 4                    Student
#                 ...
# 3995    Working Professional
# 3996    Working Professional
# 3997                 Retired
# 3998    Working Professional
# 3999    Working Professional
# Name: Professional Status, Length: 4000, dtype: object

# %%
df['Professional Status'].isnull().max()
# Out:
# np.False_

# %% [markdown]
# #just checking manually, whether there are any 0 values

# %%
pd.set_option('display.max_rows', None)

# %%
display(df)

# %% [markdown]
# #trying to find the rows with Single Retired People, 'srp_df'

# %%
options = ['Retired'] 
 

srp_df = df.loc[(df['Marital Status'] == 'Single') & 
              df['Professional Status'].isin(options)] 
srp_df.head(15)
# Out:
#      User ID  Age  Gender  Annual Income Membership Type  Membership Duration  \
# 1          2   65    Male          59056           Basic                   26
# 9         10   68    Male          66916           Basic                   36
# 20        21   64    Male          92226         Premium                   35
# 29        30   69  Female         104543           Basic                    1
# 31        32   69    Male         120896         Premium                   19
# 40        41   69  Female         141771         Premium                   56
# 104      105   67    Male          94931             VIP                   48
# 114      115   68  Female          51272         Premium                   30
# 123      124   66  Female         148494         Premium                   11
# 130      131   61    Male          53152           Basic                    3
# 138      139   64    Male         109609           Basic                   10
# ...

# %% [markdown]
# #So now, that I have found all the single retired people, lets calculate, what is the count of men and women, who are retired and single

# %%
options = ['Retired'] 
 

srp_df = df.loc[(df['Marital Status'] == 'Single') & df['Professional Status'].isin(options)] 
srp_df['Gender'].value_counts()
# Out:
# Gender
# Male      163
# Female    157
# Other      20
# Name: count, dtype: int64

# %% [markdown]
# #So now we know, that we have 163 retired men and 157 retired women, who are going to the gym, lets see, who is going in the morning, and who is going in the afternoon

# %%
options = ['Retired'] 
srp_df = df.loc[(df['Marital Status'] == 'Single') & df['Professional Status'].isin(options)] 
srp_df['Preferred Time'].value_counts()
# Out:
# Preferred Time
# Morning      146
# Afternoon     99
# Evening       95
# Name: count, dtype: int64

# %% [markdown]
# Now we see who is joining at what time, lets see, who is joining morning more often, women or men

# %% [markdown]
# This is for Male

# %%
options = ['Retired'] 
srp_df = df.loc[(df['Marital Status'] == 'Single') &(df['Gender']== 'Male') & df['Professional Status'].isin(options)] 
srp_df['Preferred Time'].value_counts()
# Out:
# Preferred Time
# Morning      72
# Afternoon    50
# Evening      41
# Name: count, dtype: int64

# %% [markdown]
# This is for the Women

# %%
options = ['Retired'] 
srp_df = df.loc[(df['Marital Status'] == 'Single') &(df['Gender']== 'Female') & df['Professional Status'].isin(options)] 
srp_df['Preferred Time'].value_counts()
# Out:
# Preferred Time
# Morning      62
# Evening      49
# Afternoon    46
# Name: count, dtype: int64

# %% [markdown]
# And for the other gender types, that are provided in the data frame

# %%
options = ['Retired'] 
srp_df = df.loc[(df['Marital Status'] == 'Single') &(df['Gender']== 'Other') & df['Professional Status'].isin(options)] 
srp_df['Preferred Time'].value_counts()
# Out:
# Preferred Time
# Morning      12
# Evening       5
# Afternoon     3
# Name: count, dtype: int64

# %% [markdown]
# Now lets see, who is going to the gym more often, male, female or other

# %%
options = ['Retired'] 
srp_df = df.loc[(df['Marital Status'] == 'Single') &(df['Gender']== 'Other') & df['Professional Status'].isin(options)] 
print('Other Gender are going in average',srp_df['Frequency of Visit'].value_counts().mean().round(),'times')
srp_df = df.loc[(df['Marital Status'] == 'Single') &(df['Gender']== 'Male') & df['Professional Status'].isin(options)] 
print('Men are going in average',srp_df['Frequency of Visit'].value_counts().mean().round(),'times')
srp_df = df.loc[(df['Marital Status'] == 'Single') &(df['Gender']== 'Female') & df['Professional Status'].isin(options)] 
print('Women are going in average',srp_df['Frequency of Visit'].value_counts().mean().round(),'times')
# Out:
# Other Gender are going in average 4.0 times
# Men are going in average 27.0 times
# Women are going in average 26.0 times

# %% [markdown]
# #Now I want to see, out our specifies category, what is the average income

# %%
df.columns
# Out:
# Index(['User ID', 'Age', 'Gender', 'Annual Income', 'Membership Type',
#        'Membership Duration', 'Frequency of Visit', 'Preferred Time',
#        'Previous Membership', 'Marital Status', 'Location',
#        'Promotion Response', 'Health Condition', 'Membership Prediction',
#        'Professional', 'Professional Status'],
#       dtype='object')

# %%
Retired_df = df[(df['Marital Status'] == 'Single') & (df['Professional Status'] == 'Retired')]
Retired_df.head(5)
# Out:
#     User ID  Age  Gender  Annual Income Membership Type  Membership Duration  \
# 1         2   65    Male          59056           Basic                   26
# 9        10   68    Male          66916           Basic                   36
# 20       21   64    Male          92226         Premium                   35
# 29       30   69  Female         104543           Basic                    1
# 31       32   69    Male         120896         Premium                   19
#
#     Frequency of Visit Preferred Time Previous Membership Marital Status  \
# 1                    6      Afternoon                 Yes         Single
# 9                    4        Morning                 Yes         Single
# 20                   6        Morning                 Yes         Single
# 29                   2        Morning                  No         Single
# 31                   4        Morning                  No         Single
#
# ...

# %% [markdown]
# So now we see the average income of single retired gym members by gender

# %%
group_income = Retired_df.groupby('Gender').agg({'Annual Income': ['mean']})
group_visit = Retired_df.groupby('Gender').agg({'Frequency of Visit': ['mean']})
group_membership_duration = Retired_df.groupby('Gender').agg({'Membership Duration': ['mean']})
group_visit
group_income
group_membership_duration
gro
# Out:
#        Membership Duration
#                       mean
# Gender
# Female           29.866242
# Male             30.588957
# Other            28.550000
